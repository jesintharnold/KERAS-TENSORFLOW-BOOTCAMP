# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv("./student_data.csv");
data.head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %% [markdown]
# ***Preprocessing and EDA of student data***

# %%
# check for balanced/unbalanced data
plt.figure(figsize=(8,5))
sns.countplot(data=data,x="admit")
# Out:
# <AxesSubplot:xlabel='admit', ylabel='count'>

# %%
#Finding the correlation heatmap
plt.figure(figsize=(8,5))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Plotting a scatter plot with hue as rank
sns.scatterplot(data=data,x="gre",y="gpa",hue="rank")
# Out:
# <AxesSubplot:xlabel='gre', ylabel='gpa'>

# %%
#Plotting a scatter plot with hue as admit
sns.scatterplot(data=data,x="gre",y="gpa",hue="admit")
# Out:
# <AxesSubplot:xlabel='gre', ylabel='gpa'>

# %%
print("*"*150);
print(data.info());
print("*"*150);
data.describe().transpose()
# Out:
# ******************************************************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   admit   400 non-null    int64
#  1   gre     400 non-null    int64
#  2   gpa     400 non-null    float64
#  3   rank    400 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 12.6 KB
# None
# ******************************************************************************************************************************************************
#        count      mean         std     min     25%      50%     75%    max
# admit  400.0    0.3175    0.466087    0.00    0.00    0.000    1.00    1.0
# gre    400.0  587.7000  115.516536  220.00  520.00  580.000  660.00  800.0
# gpa    400.0    3.3899    0.380567    2.26    3.13    3.395    3.67    4.0
# rank   400.0    2.4850    0.944460    1.00    2.00    2.000    3.00    4.0

# %%
sum_of_null=pd.DataFrame(data.isnull().sum(),columns=["sum"])
sum_of_null[sum_of_null["sum"]>0]
# Out:
# Empty DataFrame
# Columns: [sum]
# Index: []

# %% [markdown]
# ***Splitting/Scaling the data***

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(data.drop("admit",axis=1),data["admit"],random_state=45,test_size=0.25);
print("X-train :",x_train.shape);
print("Y-train :",y_train.shape);
print("X-test :",x_test.shape);
print("Y-test :",y_test.shape);
# Out:
# X-train : (300, 3)
# Y-train : (300,)
# X-test : (100, 3)
# Y-test : (100,)

# %%
#Scaling the values
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()
x_train=Scaler.fit_transform(x_train);
x_test=Scaler.transform(x_test);

# %% [markdown]
# ***Training the model***

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
model=Sequential([
    Dense(100,activation="relu"),
    Dropout(0.2),
    Dense(70,activation="relu"),
    Dropout(0.2),
    Dense(10,activation="relu"),
    Dense(1,activation="sigmoid")
]);

model.compile(optimizer="adam",loss="binary_crossentropy");

# %%
Early_callback=EarlyStopping(patience=30,monitor="val_loss",mode="min",verbose=1);
model.fit(x=x_train,y=y_train,epochs=600,validation_data=(x_test,y_test),callbacks=[Early_callback],batch_size=50);
# Out:
# Epoch 1/600
# 6/6 [==============================] - 3s 245ms/step - loss: 0.7648 - val_loss: 0.7200
# Epoch 2/600
# 6/6 [==============================] - 0s 21ms/step - loss: 0.7206 - val_loss: 0.6913
# Epoch 3/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6836 - val_loss: 0.6767
# Epoch 4/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6630 - val_loss: 0.6684
# Epoch 5/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6494 - val_loss: 0.6622
# Epoch 6/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6367 - val_loss: 0.6579
# Epoch 7/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6283 - val_loss: 0.6562
# Epoch 8/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.6211 - val_loss: 0.6555
# Epoch 9/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6088 - val_loss: 0.6556
# Epoch 10/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6154 - val_loss: 0.6554
# Epoch 11/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.6034 - val_loss: 0.6542
# Epoch 12/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6040 - val_loss: 0.6511
# Epoch 13/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6008 - val_loss: 0.6481
# Epoch 14/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6010 - val_loss: 0.6438
# Epoch 15/600
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5873 - val_loss: 0.6409
# Epoch 16/600
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5900 - val_loss: 0.6380
# Epoch 17/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5775 - val_loss: 0.6387
# Epoch 18/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5794 - val_loss: 0.6368
# Epoch 19/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5772 - val_loss: 0.6316
# Epoch 20/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5816 - val_loss: 0.6321
# Epoch 21/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5800 - val_loss: 0.6281
# Epoch 22/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5832 - val_loss: 0.6269
# Epoch 23/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5819 - val_loss: 0.6287
# Epoch 24/600
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5717 - val_loss: 0.6244
# Epoch 25/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5792 - val_loss: 0.6294
# Epoch 26/600
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5727 - val_loss: 0.6314
# Epoch 27/600
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5704 - val_loss: 0.6316
# Epoch 28/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5825 - val_loss: 0.6328
# Epoch 29/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5748 - val_loss: 0.6269
# Epoch 30/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5738 - val_loss: 0.6242
# Epoch 31/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5810 - val_loss: 0.6247
# Epoch 32/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5715 - val_loss: 0.6251
# Epoch 33/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5670 - val_loss: 0.6251
# Epoch 34/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5746 - val_loss: 0.6236
# Epoch 35/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5671 - val_loss: 0.6271
# Epoch 36/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5629 - val_loss: 0.6248
# Epoch 37/600
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5748 - val_loss: 0.6237
# Epoch 38/600
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5739 - val_loss: 0.6213
# Epoch 39/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5757 - val_loss: 0.6287
# Epoch 40/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5849 - val_loss: 0.6309
# Epoch 41/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5701 - val_loss: 0.6206
# Epoch 42/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5696 - val_loss: 0.6207
# Epoch 43/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5714 - val_loss: 0.6230
# Epoch 44/600
# 6/6 [==============================] - 0s 62ms/step - loss: 0.5698 - val_loss: 0.6240
# Epoch 45/600
# 6/6 [==============================] - 0s 35ms/step - loss: 0.5769 - val_loss: 0.6233
# Epoch 46/600
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5678 - val_loss: 0.6238
# Epoch 47/600
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5656 - val_loss: 0.6221
# Epoch 48/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5703 - val_loss: 0.6192
# Epoch 49/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5669 - val_loss: 0.6201
# Epoch 50/600
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5708 - val_loss: 0.6273
# Epoch 51/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5729 - val_loss: 0.6213
# Epoch 52/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5691 - val_loss: 0.6170
# Epoch 53/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5683 - val_loss: 0.6161
# Epoch 54/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5758 - val_loss: 0.6205
# Epoch 55/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5709 - val_loss: 0.6235
# Epoch 56/600
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5634 - val_loss: 0.6251
# Epoch 57/600
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5677 - val_loss: 0.6238
# Epoch 58/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5754 - val_loss: 0.6225
# Epoch 59/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5788 - val_loss: 0.6243
# Epoch 60/600
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5729 - val_loss: 0.6173
# Epoch 61/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5729 - val_loss: 0.6186
# Epoch 62/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5735 - val_loss: 0.6193
# Epoch 63/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5646 - val_loss: 0.6206
# Epoch 64/600
# 6/6 [==============================] - 0s 50ms/step - loss: 0.5696 - val_loss: 0.6183
# Epoch 65/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5633 - val_loss: 0.6211
# Epoch 66/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5759 - val_loss: 0.6227
# Epoch 67/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5734 - val_loss: 0.6195
# Epoch 68/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5675 - val_loss: 0.6187
# Epoch 69/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5708 - val_loss: 0.6189
# Epoch 70/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5684 - val_loss: 0.6211
# Epoch 71/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5624 - val_loss: 0.6195
# Epoch 72/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5688 - val_loss: 0.6165
# Epoch 73/600
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5661 - val_loss: 0.6191
# Epoch 74/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5627 - val_loss: 0.6182
# Epoch 75/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5729 - val_loss: 0.6149
# Epoch 76/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5713 - val_loss: 0.6152
# Epoch 77/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5707 - val_loss: 0.6213
# Epoch 78/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5692 - val_loss: 0.6165
# Epoch 79/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5691 - val_loss: 0.6171
# Epoch 80/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5784 - val_loss: 0.6174
# Epoch 81/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5715 - val_loss: 0.6164
# Epoch 82/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5612 - val_loss: 0.6167
# Epoch 83/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5642 - val_loss: 0.6205
# Epoch 84/600
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5682 - val_loss: 0.6192
# Epoch 85/600
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5698 - val_loss: 0.6201
# Epoch 86/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5684 - val_loss: 0.6133
# Epoch 87/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5694 - val_loss: 0.6150
# Epoch 88/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5640 - val_loss: 0.6166
# Epoch 89/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5684 - val_loss: 0.6221
# Epoch 90/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5645 - val_loss: 0.6159
# Epoch 91/600
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5681 - val_loss: 0.6168
# Epoch 92/600
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5658 - val_loss: 0.6183
# Epoch 93/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5676 - val_loss: 0.6192
# Epoch 94/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5631 - val_loss: 0.6148
# Epoch 95/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5649 - val_loss: 0.6137
# Epoch 96/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5670 - val_loss: 0.6124
# Epoch 97/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5631 - val_loss: 0.6156
# Epoch 98/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5657 - val_loss: 0.6164
# Epoch 99/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5636 - val_loss: 0.6163
# Epoch 100/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5561 - val_loss: 0.6140
# Epoch 101/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5633 - val_loss: 0.6094
# Epoch 102/600
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5647 - val_loss: 0.6064
# Epoch 103/600
# 6/6 [==============================] - 0s 42ms/step - loss: 0.5527 - val_loss: 0.6080
# Epoch 104/600
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5672 - val_loss: 0.6146
# Epoch 105/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5658 - val_loss: 0.6197
# Epoch 106/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5665 - val_loss: 0.6151
# Epoch 107/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5597 - val_loss: 0.6094
# Epoch 108/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5602 - val_loss: 0.6072
# Epoch 109/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5551 - val_loss: 0.6122
# Epoch 110/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5615 - val_loss: 0.6184
# Epoch 111/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5616 - val_loss: 0.6141
# Epoch 112/600
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5636 - val_loss: 0.6071
# Epoch 113/600
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5677 - val_loss: 0.6077
# Epoch 114/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5608 - val_loss: 0.6099
# Epoch 115/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5636 - val_loss: 0.6157
# Epoch 116/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5528 - val_loss: 0.6136
# Epoch 117/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5571 - val_loss: 0.6101
# Epoch 118/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5595 - val_loss: 0.6107
# Epoch 119/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5558 - val_loss: 0.6145
# Epoch 120/600
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5636 - val_loss: 0.6125
# Epoch 121/600
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5657 - val_loss: 0.6082
# Epoch 122/600
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5670 - val_loss: 0.6087
# Epoch 123/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5610 - val_loss: 0.6087
# Epoch 124/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5637 - val_loss: 0.6099
# Epoch 125/600
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5507 - val_loss: 0.6114
# Epoch 126/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5498 - val_loss: 0.6092
# Epoch 127/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5596 - val_loss: 0.6119
# Epoch 128/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5621 - val_loss: 0.6128
# Epoch 129/600
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5614 - val_loss: 0.6072
# Epoch 130/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5560 - val_loss: 0.6116
# Epoch 131/600
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5590 - val_loss: 0.6145
# Epoch 132/600
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5552 - val_loss: 0.6147
# Epoch 132: early stopping

# %%
__los__=pd.DataFrame(model.history.history);
__los__.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report,confusion_matrix
__pred__=model.predict(x_test);
__binary_pred__=(__pred__>0.5).astype("int32");
val=pd.DataFrame(__binary_pred__);
print(y_test.value_counts());
print(val.value_counts());
# Out:
# 4/4 [==============================] - 0s 5ms/step
# 0    64
# 1    36
# Name: admit, dtype: int64
# 0    88
# 1    12
# dtype: int64

# %%
# Classification Report and Confusion Matrix
print(classification_report(y_test,__binary_pred__))
sns.heatmap(confusion_matrix(y_test,__binary_pred__),annot=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.95      0.80        64
#            1       0.75      0.25      0.38        36
#
#     accuracy                           0.70       100
#    macro avg       0.72      0.60      0.59       100
# weighted avg       0.71      0.70      0.65       100
# <AxesSubplot:>
